# %% [markdown]
# # **Import Library and global parameters**

# %%
import numpy as np
import pandas as pd
import os
import re
from sklearn.base import clone
from sklearn.metrics import cohen_kappa_score
from sklearn.model_selection import StratifiedKFold
from scipy.optimize import minimize
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import polars as pl
import polars.selectors as cs
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator, FormatStrFormatter, PercentFormatter
import seaborn as sns

from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Dense
from keras.optimizers import Adam
import torch
import torch.nn as nn
import torch.optim as optim

from colorama import Fore, Style
from IPython.display import clear_output
import warnings
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import VotingRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.pipeline import Pipeline
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %%
import random
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
seed_everything(2024)

# %%
SEED = 42
n_splits = 5

# %% [markdown]
# # Feature Engineering

# %%
def process_file(filename, dirname):
    df = pd.read_parquet(os.path.join(dirname, filename, 'part-0.parquet'))
    df.drop('step', axis=1, inplace=True)
    return df.describe().values.reshape(-1), filename.split('=')[1]

def load_time_series(dirname) -> pd.DataFrame:
    ids = os.listdir(dirname)
    
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(lambda fname: process_file(fname, dirname), ids), total=len(ids)))
    
    stats, indexes = zip(*results)
    
    df = pd.DataFrame(stats, columns=[f"stat_{i}" for i in range(len(stats[0]))])
    df['id'] = indexes
    return df


class AutoEncoder(nn.Module):
    def __init__(self, input_dim, encoding_dim):
        super(AutoEncoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, encoding_dim*3),
            nn.ReLU(),
            nn.Linear(encoding_dim*3, encoding_dim*2),
            nn.ReLU(),
            nn.Linear(encoding_dim*2, encoding_dim),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, input_dim*2),
            nn.ReLU(),
            nn.Linear(input_dim*2, input_dim*3),
            nn.ReLU(),
            nn.Linear(input_dim*3, input_dim),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded


def perform_autoencoder(df, encoding_dim=50, epochs=50, batch_size=32):
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(df)
    
    data_tensor = torch.FloatTensor(df_scaled)
    
    input_dim = data_tensor.shape[1]
    autoencoder = AutoEncoder(input_dim, encoding_dim)
    
    criterion = nn.MSELoss()
    optimizer = optim.Adam(autoencoder.parameters())
    
    for epoch in range(epochs):
        for i in range(0, len(data_tensor), batch_size):
            batch = data_tensor[i : i + batch_size]
            optimizer.zero_grad()
            reconstructed = autoencoder(batch)
            loss = criterion(reconstructed, batch)
            loss.backward()
            optimizer.step()
            
        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}]')
                 
    with torch.no_grad():
        encoded_data = autoencoder.encoder(data_tensor).numpy()
        
    df_encoded = pd.DataFrame(encoded_data, columns=[f'Enc_{i + 1}' for i in range(encoded_data.shape[1])])
    
    return df_encoded

def feature_engineering(df):
    season_cols = [col for col in df.columns if 'Season' in col]
    df = df.drop(season_cols, axis=1) 
    df['BMI_Age'] = df['Physical-BMI'] * df['Basic_Demos-Age']
    df['Internet_Hours_Age'] = df['PreInt_EduHx-computerinternet_hoursday'] * df['Basic_Demos-Age']
    df['BMI_Internet_Hours'] = df['Physical-BMI'] * df['PreInt_EduHx-computerinternet_hoursday']
    df['BFP_BMI'] = df['BIA-BIA_Fat'] / df['BIA-BIA_BMI']
    df['FFMI_BFP'] = df['BIA-BIA_FFMI'] / df['BIA-BIA_Fat']
    df['FMI_BFP'] = df['BIA-BIA_FMI'] / df['BIA-BIA_Fat']
    df['LST_TBW'] = df['BIA-BIA_LST'] / df['BIA-BIA_TBW']
    df['BFP_BMR'] = df['BIA-BIA_Fat'] * df['BIA-BIA_BMR']
    df['BFP_DEE'] = df['BIA-BIA_Fat'] * df['BIA-BIA_DEE']
    df['BMR_Weight'] = df['BIA-BIA_BMR'] / df['Physical-Weight']
    df['DEE_Weight'] = df['BIA-BIA_DEE'] / df['Physical-Weight']
    df['SMM_Height'] = df['BIA-BIA_SMM'] / df['Physical-Height']
    df['Muscle_to_Fat'] = df['BIA-BIA_SMM'] / df['BIA-BIA_FMI']
    df['Hydration_Status'] = df['BIA-BIA_TBW'] / df['Physical-Weight']
    df['ICW_TBW'] = df['BIA-BIA_ICW'] / df['BIA-BIA_TBW']
    df['BMI_PHR'] = df['Physical-BMI'] * df['Physical-HeartRate']
    
    return df

# %%
train = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/train.csv')
test = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/test.csv')
sample = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv')

train_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_train.parquet")
test_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_test.parquet")

df_train = train_ts.drop('id', axis=1)
df_test = test_ts.drop('id', axis=1)

train_ts_encoded = perform_autoencoder(df_train, encoding_dim=60, epochs=100, batch_size=32)
test_ts_encoded = perform_autoencoder(df_test, encoding_dim=60, epochs=100, batch_size=32)

time_series_cols = train_ts_encoded.columns.tolist()
train_ts_encoded["id"]=train_ts["id"]
test_ts_encoded['id']=test_ts["id"]

train = pd.merge(train, train_ts_encoded, how="left", on='id')
test = pd.merge(test, test_ts_encoded, how="left", on='id')

imputer = KNNImputer(n_neighbors=5)
numeric_cols = train.select_dtypes(include=['float64', 'int64']).columns
imputed_data = imputer.fit_transform(train[numeric_cols])
train_imputed = pd.DataFrame(imputed_data, columns=numeric_cols)
train_imputed['sii'] = train_imputed['sii'].round().astype(int)
for col in train.columns:
    if col not in numeric_cols:
        train_imputed[col] = train[col]
        
train = train_imputed

train = feature_engineering(train)
train = train.dropna(thresh=10, axis=0)
test = feature_engineering(test)

train = train.drop('id', axis=1)
test  = test .drop('id', axis=1)   


featuresCols = ['Basic_Demos-Age', 'Basic_Demos-Sex',
                'CGAS-CGAS_Score', 'Physical-BMI',
                'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
                'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
                'Fitness_Endurance-Max_Stage',
                'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
                'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
                'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
                'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
                'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone',
                'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
                'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
                'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
                'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
                'BIA-BIA_TBW', 'PAQ_A-PAQ_A_Total',
                'PAQ_C-PAQ_C_Total', 'SDS-SDS_Total_Raw',
                'SDS-SDS_Total_T',
                'PreInt_EduHx-computerinternet_hoursday', 'sii', 'BMI_Age','Internet_Hours_Age','BMI_Internet_Hours',
                'BFP_BMI', 'FFMI_BFP', 'FMI_BFP', 'LST_TBW', 'BFP_BMR', 'BFP_DEE', 'BMR_Weight', 'DEE_Weight',
                'SMM_Height', 'Muscle_to_Fat', 'Hydration_Status', 'ICW_TBW','BMI_PHR']

featuresCols += time_series_cols

train = train[featuresCols]
train = train.dropna(subset='sii')

featuresCols = ['Basic_Demos-Age', 'Basic_Demos-Sex',
                'CGAS-CGAS_Score', 'Physical-BMI',
                'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
                'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
                'Fitness_Endurance-Max_Stage',
                'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
                'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
                'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
                'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
                'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone',
                'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
                'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
                'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
                'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
                'BIA-BIA_TBW', 'PAQ_A-PAQ_A_Total',
                'PAQ_C-PAQ_C_Total', 'SDS-SDS_Total_Raw',
                'SDS-SDS_Total_T',
                'PreInt_EduHx-computerinternet_hoursday', 'BMI_Age','Internet_Hours_Age','BMI_Internet_Hours',
                'BFP_BMI', 'FFMI_BFP', 'FMI_BFP', 'LST_TBW', 'BFP_BMR', 'BFP_DEE', 'BMR_Weight', 'DEE_Weight',
                'SMM_Height', 'Muscle_to_Fat', 'Hydration_Status', 'ICW_TBW','BMI_PHR']

featuresCols += time_series_cols
test = test[featuresCols]
# Out:
# 100%|██████████| 996/996 [01:20<00:00, 12.44it/s]
# 100%|██████████| 2/2 [00:00<00:00,  9.57it/s]
# Epoch [10/100], Loss: 1.6378]
# Epoch [20/100], Loss: 1.5450]
# Epoch [30/100], Loss: 1.5127]
# Epoch [40/100], Loss: 1.5011]
# Epoch [50/100], Loss: 1.5013]
# Epoch [60/100], Loss: 1.5026]
# Epoch [70/100], Loss: 1.4933]
# Epoch [80/100], Loss: 1.4747]
# Epoch [90/100], Loss: 1.4714]
# Epoch [100/100], Loss: 1.4555]
# Epoch [10/100], Loss: 1.0070]
# Epoch [20/100], Loss: 0.5783]
# Epoch [30/100], Loss: 0.4271]
# Epoch [40/100], Loss: 0.4271]
# Epoch [50/100], Loss: 0.4271]
# Epoch [60/100], Loss: 0.4271]
# Epoch [70/100], Loss: 0.4271]
# Epoch [80/100], Loss: 0.4271]
# Epoch [90/100], Loss: 0.4271]
# Epoch [100/100], Loss: 0.4271]

# %%
if np.any(np.isinf(train)):
    train = train.replace([np.inf, -np.inf], np.nan)

def quadratic_weighted_kappa(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights='quadratic')

def threshold_Rounder(oof_non_rounded, thresholds):
    return np.where(oof_non_rounded < thresholds[0], 0,
                    np.where(oof_non_rounded < thresholds[1], 1,
                             np.where(oof_non_rounded < thresholds[2], 2, 3)))

def evaluate_predictions(thresholds, y_true, oof_non_rounded):
    rounded_p = threshold_Rounder(oof_non_rounded, thresholds)
    return -quadratic_weighted_kappa(y_true, rounded_p)

# %%
def TrainML(model_class, test_data):
    X = train.drop(['sii'], axis=1)
    y = train['sii']

    SKF = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 
    test_preds = np.zeros((len(test_data), n_splits))

    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = clone(model_class)
        model.fit(X_train, y_train)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)
        
        test_preds[:, fold] = model.predict(test_data)
        
        print(f"Fold {fold+1} - Train QWK: {train_kappa:.4f}, Validation QWK: {val_kappa:.4f}")
        clear_output(wait=True)

    print(f"Mean Train QWK --> {np.mean(train_S):.4f}")
    print(f"Mean Validation QWK ---> {np.mean(test_S):.4f}")

    KappaOPtimizer = minimize(evaluate_predictions,
                              x0=[0.5, 1.5, 2.5], args=(y, oof_non_rounded), 
                              method='Nelder-Mead')
    assert KappaOPtimizer.success, "Optimization did not converge."
    
    oof_tuned = threshold_Rounder(oof_non_rounded, KappaOPtimizer.x)
    tKappa = quadratic_weighted_kappa(y, oof_tuned)

    print(f"----> || Optimized QWK SCORE :: {Fore.CYAN}{Style.BRIGHT} {tKappa:.3f}{Style.RESET_ALL}")

    tpm = test_preds.mean(axis=1)
    tpTuned = threshold_Rounder(tpm, KappaOPtimizer.x)
    
    submission = pd.DataFrame({
        'id': sample['id'],
        'sii': tpTuned
    })

    return submission

# %% [markdown]
# # Model training and evaluation

# %% [markdown]
# # XGB

# %%
import optuna  # pip install optuna
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold


def objective(trial, X, y):
    param_grid = {
        'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.008,0.01,0.012,0.014,0.016,0.018, 0.02]),
        'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15,17]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    }

    SKF = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 


    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = XGBRegressor(**param_grid,random_state=SEED,n_estimators=10000)
        #model.fit(X_train, y_train)
        model.fit(X_train,y_train,eval_set=[(X_val,y_val)],early_stopping_rounds=100,verbose=False)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)

    return np.mean(test_S)

# %%
X = train.drop(['sii'], axis=1)
y = train['sii']

# %%
study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective(trial, X, y), n_trials=50)
# Out:
# [I 2024-12-18 15:44:59,010] A new study created in memory with name: no-name-cae4acba-4642-4cca-a3a8-491b060f246e
# Training Folds: 100%|██████████| 5/5 [00:36<00:00,  7.33s/it]
# [I 2024-12-18 15:45:35,692] Trial 0 finished with value: 0.4871703450698298 and parameters: {'lambda': 3.894175243920765, 'alpha': 0.01463135994599057, 'colsample_bytree': 0.9, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 13, 'min_child_weight': 123}. Best is trial 0 with value: 0.4871703450698298.
# Training Folds: 100%|██████████| 5/5 [00:29<00:00,  6.00s/it]
# [I 2024-12-18 15:46:05,687] Trial 1 finished with value: 0.48991891774080293 and parameters: {'lambda': 0.0020548852686789057, 'alpha': 2.342376779786357, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.016, 'max_depth': 15, 'min_child_weight': 158}. Best is trial 1 with value: 0.48991891774080293.
# Training Folds: 100%|██████████| 5/5 [00:34<00:00,  6.88s/it]
# [I 2024-12-18 15:46:40,112] Trial 2 finished with value: 0.48902213918133447 and parameters: {'lambda': 2.9854346749347407, 'alpha': 0.26295630219373106, 'colsample_bytree': 0.9, 'subsample': 0.5, 'learning_rate': 0.02, 'max_depth': 13, 'min_child_weight': 24}. Best is trial 1 with value: 0.48991891774080293.
# Training Folds: 100%|██████████| 5/5 [00:43<00:00,  8.75s/it]
# [I 2024-12-18 15:47:23,864] Trial 3 finished with value: 0.5084214239398407 and parameters: {'lambda': 0.17397506024822376, 'alpha': 0.6062642324176627, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.016, 'max_depth': 17, 'min_child_weight': 47}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:30<00:00,  6.07s/it]
# [I 2024-12-18 15:47:54,237] Trial 4 finished with value: 0.47232523568838714 and parameters: {'lambda': 1.5987691834216127, 'alpha': 0.4883272464547976, 'colsample_bytree': 0.3, 'subsample': 0.6, 'learning_rate': 0.016, 'max_depth': 7, 'min_child_weight': 232}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:31<00:00,  6.23s/it]
# [I 2024-12-18 15:48:25,402] Trial 5 finished with value: 0.4907349606261008 and parameters: {'lambda': 3.351549601885827, 'alpha': 0.0019103558537546532, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.016, 'max_depth': 11, 'min_child_weight': 103}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [01:11<00:00, 14.34s/it]
# [I 2024-12-18 15:49:37,094] Trial 6 finished with value: 0.49977503194354134 and parameters: {'lambda': 0.019546137883745845, 'alpha': 1.8688053293927547, 'colsample_bytree': 0.7, 'subsample': 1.0, 'learning_rate': 0.012, 'max_depth': 15, 'min_child_weight': 38}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:36<00:00,  7.22s/it]
# [I 2024-12-18 15:50:13,198] Trial 7 finished with value: 0.47475444911635095 and parameters: {'lambda': 1.0095564651231044, 'alpha': 0.19894001874967002, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.014, 'max_depth': 5, 'min_child_weight': 281}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:35<00:00,  7.01s/it]
# [I 2024-12-18 15:50:48,273] Trial 8 finished with value: 0.4770542711534901 and parameters: {'lambda': 0.030675840091085416, 'alpha': 0.0013643939176102612, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.016, 'max_depth': 7, 'min_child_weight': 187}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:38<00:00,  7.72s/it]
# [I 2024-12-18 15:51:26,897] Trial 9 finished with value: 0.484743507939994 and parameters: {'lambda': 0.029659215246333425, 'alpha': 0.01949449571149373, 'colsample_bytree': 0.3, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 177}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [02:17<00:00, 27.59s/it]
# [I 2024-12-18 15:53:44,876] Trial 10 finished with value: 0.5046048434590814 and parameters: {'lambda': 0.15949988101152315, 'alpha': 8.428110240872915, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 67}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [02:09<00:00, 25.91s/it]
# [I 2024-12-18 15:55:54,473] Trial 11 finished with value: 0.5059622165061162 and parameters: {'lambda': 0.2602406156808157, 'alpha': 6.695487463865004, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 64}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [01:59<00:00, 23.85s/it]
# [I 2024-12-18 15:57:53,724] Trial 12 finished with value: 0.5036258613705896 and parameters: {'lambda': 0.2370434015951754, 'alpha': 5.742006974141705, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 73}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [05:48<00:00, 69.68s/it]
# [I 2024-12-18 16:03:42,137] Trial 13 finished with value: 0.49933387712578525 and parameters: {'lambda': 0.283486891816974, 'alpha': 1.3121234460068116, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 6}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:33<00:00,  6.78s/it]
# [I 2024-12-18 16:04:16,084] Trial 14 finished with value: 0.475384820874302 and parameters: {'lambda': 0.5502898370207355, 'alpha': 0.03844861493897962, 'colsample_bytree': 1.0, 'subsample': 0.4, 'learning_rate': 0.012, 'max_depth': 9, 'min_child_weight': 83}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:39<00:00,  7.93s/it]
# [I 2024-12-18 16:04:55,771] Trial 15 finished with value: 0.5004172639561617 and parameters: {'lambda': 0.08057041243868075, 'alpha': 0.7110971411443087, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.014, 'max_depth': 17, 'min_child_weight': 48}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:23<00:00,  4.76s/it]
# [I 2024-12-18 16:05:19,610] Trial 16 finished with value: 0.4871376473882763 and parameters: {'lambda': 0.006908113837939528, 'alpha': 0.08723543003793795, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 116}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:48<00:00,  9.64s/it]
# [I 2024-12-18 16:06:07,835] Trial 17 finished with value: 0.4813662504461124 and parameters: {'lambda': 0.06478840500126931, 'alpha': 4.532313973132153, 'colsample_bytree': 0.5, 'subsample': 0.4, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 130}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [05:27<00:00, 65.56s/it]
# [I 2024-12-18 16:11:35,662] Trial 18 finished with value: 0.49233311278354924 and parameters: {'lambda': 9.90915539188826, 'alpha': 0.8402112344571998, 'colsample_bytree': 0.8, 'subsample': 1.0, 'learning_rate': 0.02, 'max_depth': 11, 'min_child_weight': 1}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [01:06<00:00, 13.22s/it]
# [I 2024-12-18 16:12:41,806] Trial 19 finished with value: 0.5045102703745868 and parameters: {'lambda': 0.4688653281034275, 'alpha': 2.7817077257682676, 'colsample_bytree': 0.4, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 55}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [00:51<00:00, 10.39s/it]
# [I 2024-12-18 16:13:33,805] Trial 20 finished with value: 0.4942097066286955 and parameters: {'lambda': 0.008237271776406863, 'alpha': 0.0049548420287974775, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 98}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [02:14<00:00, 26.92s/it]
# [I 2024-12-18 16:15:48,447] Trial 21 finished with value: 0.50523580307977 and parameters: {'lambda': 0.13405712798127858, 'alpha': 9.764304611552106, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 69}. Best is trial 3 with value: 0.5084214239398407.
# Training Folds: 100%|██████████| 5/5 [02:51<00:00, 34.26s/it]
# [I 2024-12-18 16:18:39,781] Trial 22 finished with value: 0.5126521256007343 and parameters: {'lambda': 0.155833278223442, 'alpha': 9.375727204121594, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 30}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [03:33<00:00, 42.74s/it]
# [I 2024-12-18 16:22:13,526] Trial 23 finished with value: 0.5087029419874229 and parameters: {'lambda': 0.07616755717520256, 'alpha': 2.960062368188106, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 18}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:52<00:00, 10.55s/it]
# [I 2024-12-18 16:23:06,314] Trial 24 finished with value: 0.49903780488171445 and parameters: {'lambda': 0.05464142007262555, 'alpha': 0.3890095816960476, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.016, 'max_depth': 17, 'min_child_weight': 29}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [02:27<00:00, 29.52s/it]
# [I 2024-12-18 16:25:33,963] Trial 25 finished with value: 0.49429559434924375 and parameters: {'lambda': 0.01177706277407315, 'alpha': 1.2630730158053696, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 18}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:56<00:00, 11.27s/it]
# [I 2024-12-18 16:26:30,353] Trial 26 finished with value: 0.4946402147743319 and parameters: {'lambda': 0.7599947149751385, 'alpha': 2.9732532490153076, 'colsample_bytree': 0.7, 'subsample': 0.4, 'learning_rate': 0.01, 'max_depth': 7, 'min_child_weight': 42}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:01<00:00, 12.36s/it]
# [I 2024-12-18 16:27:32,172] Trial 27 finished with value: 0.49014807043138353 and parameters: {'lambda': 0.002591424368539221, 'alpha': 0.12770723936599887, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.014, 'max_depth': 11, 'min_child_weight': 19}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:48<00:00,  9.79s/it]
# [I 2024-12-18 16:28:21,149] Trial 28 finished with value: 0.49017845223158274 and parameters: {'lambda': 0.10536219512234223, 'alpha': 3.93334832064487, 'colsample_bytree': 0.9, 'subsample': 0.5, 'learning_rate': 0.012, 'max_depth': 13, 'min_child_weight': 87}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:33<00:00,  6.73s/it]
# [I 2024-12-18 16:28:54,807] Trial 29 finished with value: 0.4906754733598081 and parameters: {'lambda': 0.04836310922952467, 'alpha': 1.3339918854374857, 'colsample_bytree': 0.8, 'subsample': 1.0, 'learning_rate': 0.018, 'max_depth': 9, 'min_child_weight': 138}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:20<00:00,  4.17s/it]
# [I 2024-12-18 16:29:15,708] Trial 30 finished with value: 0.4907096007097224 and parameters: {'lambda': 0.37326674148820965, 'alpha': 0.06618799510549449, 'colsample_bytree': 0.4, 'subsample': 0.5, 'learning_rate': 0.02, 'max_depth': 5, 'min_child_weight': 46}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:53<00:00, 22.60s/it]
# [I 2024-12-18 16:31:08,736] Trial 31 finished with value: 0.5025614510605892 and parameters: {'lambda': 0.14734471194041932, 'alpha': 5.90506566527275, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 59}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [06:37<00:00, 79.59s/it]
# [I 2024-12-18 16:37:46,738] Trial 32 finished with value: 0.504740623841685 and parameters: {'lambda': 0.24028847355926158, 'alpha': 8.74660093102347, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 15, 'min_child_weight': 3}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [02:27<00:00, 29.42s/it]
# [I 2024-12-18 16:40:13,849] Trial 33 finished with value: 0.5066430639316818 and parameters: {'lambda': 1.381110823143897, 'alpha': 2.2438789398982277, 'colsample_bytree': 1.0, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 28}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:09<00:00, 13.87s/it]
# [I 2024-12-18 16:41:23,237] Trial 34 finished with value: 0.5065497162714852 and parameters: {'lambda': 1.614085711723533, 'alpha': 2.39075737818431, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.016, 'max_depth': 13, 'min_child_weight': 25}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:41<00:00,  8.38s/it]
# [I 2024-12-18 16:42:05,167] Trial 35 finished with value: 0.48677753714385014 and parameters: {'lambda': 8.330176853893763, 'alpha': 0.6859342377266938, 'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.016, 'max_depth': 17, 'min_child_weight': 214}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:04<00:00, 13.00s/it]
# [I 2024-12-18 16:43:10,179] Trial 36 finished with value: 0.4995344232279678 and parameters: {'lambda': 1.7955686221805383, 'alpha': 0.308703855389936, 'colsample_bytree': 0.3, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 15, 'min_child_weight': 26}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:28<00:00,  5.75s/it]
# [I 2024-12-18 16:43:38,964] Trial 37 finished with value: 0.493613375515819 and parameters: {'lambda': 0.9552334000974396, 'alpha': 1.973936696110364, 'colsample_bytree': 0.5, 'subsample': 0.8, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 109}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:33<00:00,  6.68s/it]
# [I 2024-12-18 16:44:12,379] Trial 38 finished with value: 0.47063209491176927 and parameters: {'lambda': 2.6160691029283174, 'alpha': 0.5046645177158988, 'colsample_bytree': 0.7, 'subsample': 0.5, 'learning_rate': 0.016, 'max_depth': 7, 'min_child_weight': 277}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:25<00:00,  5.10s/it]
# [I 2024-12-18 16:44:37,903] Trial 39 finished with value: 0.48435224846384123 and parameters: {'lambda': 4.748658214013633, 'alpha': 0.1706314094509061, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.02, 'max_depth': 13, 'min_child_weight': 156}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:48<00:00, 21.62s/it]
# [I 2024-12-18 16:46:26,055] Trial 40 finished with value: 0.5045820464015724 and parameters: {'lambda': 0.001010571632991246, 'alpha': 3.8399242589456772, 'colsample_bytree': 0.4, 'subsample': 1.0, 'learning_rate': 0.008, 'max_depth': 17, 'min_child_weight': 38}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:34<00:00, 18.97s/it]
# [I 2024-12-18 16:48:00,935] Trial 41 finished with value: 0.5046709275339654 and parameters: {'lambda': 1.4208782403177143, 'alpha': 2.0831901354948408, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.016, 'max_depth': 13, 'min_child_weight': 18}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:51<00:00, 10.35s/it]
# [I 2024-12-18 16:48:52,724] Trial 42 finished with value: 0.5023467690989193 and parameters: {'lambda': 0.03440784184197546, 'alpha': 1.1101340520930119, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.016, 'max_depth': 13, 'min_child_weight': 37}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:48<00:00, 21.80s/it]
# [I 2024-12-18 16:50:41,751] Trial 43 finished with value: 0.5043795170626785 and parameters: {'lambda': 0.6548909968278188, 'alpha': 2.6735703341087107, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.016, 'max_depth': 13, 'min_child_weight': 14}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:34<00:00,  6.99s/it]
# [I 2024-12-18 16:51:16,707] Trial 44 finished with value: 0.4996896606896056 and parameters: {'lambda': 4.597953848764165, 'alpha': 5.221493808498242, 'colsample_bytree': 0.3, 'subsample': 0.7, 'learning_rate': 0.016, 'max_depth': 13, 'min_child_weight': 86}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:44<00:00,  8.84s/it]
# [I 2024-12-18 16:52:00,926] Trial 45 finished with value: 0.4962042790673795 and parameters: {'lambda': 0.01789149574270105, 'alpha': 1.8073854681491879, 'colsample_bytree': 1.0, 'subsample': 0.6, 'learning_rate': 0.012, 'max_depth': 5, 'min_child_weight': 50}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:46<00:00, 21.21s/it]
# [I 2024-12-18 16:53:46,993] Trial 46 finished with value: 0.49999908238023966 and parameters: {'lambda': 2.218698133987768, 'alpha': 3.515147218905741, 'colsample_bytree': 0.7, 'subsample': 0.8, 'learning_rate': 0.008, 'max_depth': 11, 'min_child_weight': 28}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:35<00:00,  7.16s/it]
# [I 2024-12-18 16:54:22,844] Trial 47 finished with value: 0.49275988289006617 and parameters: {'lambda': 1.054001987494573, 'alpha': 0.5672451157218119, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.016, 'max_depth': 17, 'min_child_weight': 78}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [00:42<00:00,  8.56s/it]
# [I 2024-12-18 16:55:05,675] Trial 48 finished with value: 0.4810485432194862 and parameters: {'lambda': 0.1854069047784126, 'alpha': 0.9417904750844024, 'colsample_bytree': 0.9, 'subsample': 0.8, 'learning_rate': 0.014, 'max_depth': 15, 'min_child_weight': 178}. Best is trial 22 with value: 0.5126521256007343.
# Training Folds: 100%|██████████| 5/5 [01:29<00:00, 17.97s/it]
# [I 2024-12-18 16:56:35,538] Trial 49 finished with value: 0.498812427166475 and parameters: {'lambda': 0.3589474482205936, 'alpha': 1.71097863385142, 'colsample_bytree': 0.5, 'subsample': 0.4, 'learning_rate': 0.01, 'max_depth': 17, 'min_child_weight': 9}. Best is trial 22 with value: 0.5126521256007343.

# %%
print(f"\tBest value: {study.best_value:.5f}")
print(f"\tBest params:")

for key, value in study.best_params.items():
    print(f"\t\t{key}: {value}")
# Out:
# 	Best value: 0.51265
# 	Best params:
# 		lambda: 0.155833278223442
# 		alpha: 9.375727204121594
# 		colsample_bytree: 1.0
# 		subsample: 0.8
# 		learning_rate: 0.008
# 		max_depth: 17
# 		min_child_weight: 30

# %%
# Model parameters for LightGBM
Params = {
		'lambda': 0.155833278223442,
		'alpha': 9.375727204121594,
		'colsample_bytree': 1.0,
		'subsample': 0.8,
		'learning_rate': 0.008,
		'max_depth': 17,
		'min_child_weight': 30,
}

XGB = XGBRegressor(**Params,random_state=SEED,n_estimators=10000)

Submission = TrainML(XGB,test)

Submission
# Out:
# Training Folds: 100%|██████████| 5/5 [11:44<00:00, 140.97s/it]
# Mean Train QWK --> 0.9799
# Mean Validation QWK ---> 0.5137
# ----> || Optimized QWK SCORE ::  0.548
#           id  sii
# 0   00008ff9    1
# 1   000fd460    0
# 2   00105258    0
# 3   00115b9f    0
# 4   0016bb22    1
# 5   001f3379    0
# 6   0038ba98    0
# 7   0068a485    0
# 8   0069fbed    1
# 9   0083e397    1
# 10  0087dd65    1
# 11  00abe655    0
# 12  00ae59c9    1
# 13  00af6387    1
# 14  00bd4359    1
# 15  00c0cd71    1
# 16  00d56d4b    0
# 17  00d9913d    1
# 18  00e6167c    0
# 19  00ebc35d    1

# %%
Submission.to_csv('submission1.csv', index=False)
print(Submission['sii'].value_counts())

# %%
train = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/train.csv')
test = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/test.csv')
sample = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv')

def process_file(filename, dirname):
    df = pd.read_parquet(os.path.join(dirname, filename, 'part-0.parquet'))
    df.drop('step', axis=1, inplace=True)
    return df.describe().values.reshape(-1), filename.split('=')[1]

def load_time_series(dirname) -> pd.DataFrame:
    ids = os.listdir(dirname)
    
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(lambda fname: process_file(fname, dirname), ids), total=len(ids)))
    
    stats, indexes = zip(*results)
    
    df = pd.DataFrame(stats, columns=[f"stat_{i}" for i in range(len(stats[0]))])
    df['id'] = indexes
    return df
        
train_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_train.parquet")
test_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_test.parquet")

time_series_cols = train_ts.columns.tolist()
time_series_cols.remove("id")

train = pd.merge(train, train_ts, how="left", on='id')
test = pd.merge(test, test_ts, how="left", on='id')

train = train.drop('id', axis=1)
test = test.drop('id', axis=1)   

featuresCols = ['Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
                'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
                'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
                'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
                'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
                'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
                'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
                'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
                'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
                'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
                'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
                'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
                'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
                'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
                'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
                'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
                'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
                'PreInt_EduHx-computerinternet_hoursday', 'sii']

featuresCols += time_series_cols

train = train[featuresCols]
train = train.dropna(subset='sii')

cat_c = ['Basic_Demos-Enroll_Season', 'CGAS-Season', 'Physical-Season', 
          'Fitness_Endurance-Season', 'FGC-Season', 'BIA-Season', 
          'PAQ_A-Season', 'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season']

def update(df):
    global cat_c
    for c in cat_c: 
        df[c] = df[c].fillna('Missing')
        df[c] = df[c].astype('category')
    return df
        
train = update(train)
test = update(test)

def create_mapping(column, dataset):
    unique_values = dataset[column].unique()
    return {value: idx for idx, value in enumerate(unique_values)}

for col in cat_c:
    mapping = create_mapping(col, train)
    mappingTe = create_mapping(col, test)
    
    train[col] = train[col].replace(mapping).astype(int)
    test[col] = test[col].replace(mappingTe).astype(int)

def quadratic_weighted_kappa(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights='quadratic')

def threshold_Rounder(oof_non_rounded, thresholds):
    return np.where(oof_non_rounded < thresholds[0], 0,
                    np.where(oof_non_rounded < thresholds[1], 1,
                             np.where(oof_non_rounded < thresholds[2], 2, 3)))

def evaluate_predictions(thresholds, y_true, oof_non_rounded):
    rounded_p = threshold_Rounder(oof_non_rounded, thresholds)
    return -quadratic_weighted_kappa(y_true, rounded_p)

def TrainML(model_class, test_data):
    X = train.drop(['sii'], axis=1)
    y = train['sii']

    SKF = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 
    test_preds = np.zeros((len(test_data), n_splits))

    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = clone(model_class)
        model.fit(X_train, y_train)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)
        
        test_preds[:, fold] = model.predict(test_data)
        
        print(f"Fold {fold+1} - Train QWK: {train_kappa:.4f}, Validation QWK: {val_kappa:.4f}")
        clear_output(wait=True)

    print(f"Mean Train QWK --> {np.mean(train_S):.4f}")
    print(f"Mean Validation QWK ---> {np.mean(test_S):.4f}")

    KappaOPtimizer = minimize(evaluate_predictions,
                              x0=[0.5, 1.49, 2.5], args=(y, oof_non_rounded), 
                              method='Nelder-Mead')
    assert KappaOPtimizer.success, "Optimization did not converge."
    thresholds = KappaOPtimizer.x
    
    oof_tuned = threshold_Rounder(oof_non_rounded, thresholds)
    tKappa = quadratic_weighted_kappa(y, oof_tuned)

    print(f"----> || Optimized QWK SCORE :: {Fore.CYAN}{Style.BRIGHT} {tKappa:.3f}{Style.RESET_ALL}")

    fold_weights = [1.25, 1.0, 1.0, 1.0, 1.0]
    tpm = test_preds.dot(fold_weights) / np.sum(fold_weights)
    tpTuned = threshold_Rounder(tpm, thresholds)
    
    submission = pd.DataFrame({
        'id': sample['id'],
        'sii': tpTuned
    })

    return submission
# Out:
# 100%|██████████| 996/996 [01:20<00:00, 12.38it/s]
# 100%|██████████| 2/2 [00:00<00:00, 11.83it/s]

# %%
def TrainML(model_class, test_data):
    X = train.drop(['sii'], axis=1)
    y = train['sii']

    SKF = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 
    test_preds = np.zeros((len(test_data), n_splits))

    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = clone(model_class)
        model.fit(X_train, y_train)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)
        
        test_preds[:, fold] = model.predict(test_data)
        
        print(f"Fold {fold+1} - Train QWK: {train_kappa:.4f}, Validation QWK: {val_kappa:.4f}")
        clear_output(wait=True)

    print(f"Mean Train QWK --> {np.mean(train_S):.4f}")
    print(f"Mean Validation QWK ---> {np.mean(test_S):.4f}")

    KappaOPtimizer = minimize(evaluate_predictions,
                              x0=[0.5, 1.49, 2.5], args=(y, oof_non_rounded), 
                              method='Nelder-Mead')
    assert KappaOPtimizer.success, "Optimization did not converge."
    thresholds = KappaOPtimizer.x
    
    oof_tuned = threshold_Rounder(oof_non_rounded, thresholds)
    tKappa = quadratic_weighted_kappa(y, oof_tuned)

    print(f"----> || Optimized QWK SCORE :: {Fore.CYAN}{Style.BRIGHT} {tKappa:.3f}{Style.RESET_ALL}")

    fold_weights = [1.25, 1.0, 1.0, 1.0, 1.0]
    tpm = test_preds.dot(fold_weights) / np.sum(fold_weights)
    tpTuned = threshold_Rounder(tpm, thresholds)
    
    submission = pd.DataFrame({
        'id': sample['id'],
        'sii': tpTuned
    })

    return submission

# %%
import optuna  # pip install optuna
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold


def objective(trial, X, y):
    param_grid = {
        'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.008,0.01,0.012,0.014,0.016,0.018, 0.02]),
        'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15,17]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    }

    SKF = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 


    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = XGBRegressor(**param_grid,random_state=SEED,n_estimators=10000)
        #model.fit(X_train, y_train)
        model.fit(X_train,y_train,eval_set=[(X_val,y_val)],early_stopping_rounds=100,verbose=False)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)

    return np.mean(test_S)

# %%
X = train.drop(['sii'], axis=1)
y = train['sii']

# %%
study = optuna.create_study(direction="maximize")
study.optimize(lambda trial: objective(trial, X, y), n_trials=50)
# Out:
# [I 2024-12-18 17:16:27,434] A new study created in memory with name: no-name-7de3bba6-55fa-41ae-9a87-76ca30526209
# Training Folds: 100%|██████████| 5/5 [00:09<00:00,  1.87s/it]
# [I 2024-12-18 17:16:36,771] Trial 0 finished with value: 0.37176761893035815 and parameters: {'lambda': 0.0883874346535684, 'alpha': 0.03916034292902938, 'colsample_bytree': 0.4, 'subsample': 0.7, 'learning_rate': 0.02, 'max_depth': 17, 'min_child_weight': 195}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:29<00:00,  5.81s/it]
# [I 2024-12-18 17:17:05,830] Trial 1 finished with value: 0.3639512828889004 and parameters: {'lambda': 0.2959922821651338, 'alpha': 0.0016469505216185577, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.008, 'max_depth': 5, 'min_child_weight': 39}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:18<00:00,  3.63s/it]
# [I 2024-12-18 17:17:24,005] Trial 2 finished with value: 0.367033835059869 and parameters: {'lambda': 0.8144483849865746, 'alpha': 6.522591960925241, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.012, 'max_depth': 11, 'min_child_weight': 132}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:24<00:00,  4.84s/it]
# [I 2024-12-18 17:17:48,208] Trial 3 finished with value: 0.3643225374667415 and parameters: {'lambda': 0.016347420964593774, 'alpha': 0.7550762543005911, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.008, 'max_depth': 5, 'min_child_weight': 120}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:17<00:00,  3.51s/it]
# [I 2024-12-18 17:18:05,779] Trial 4 finished with value: 0.36906783022352235 and parameters: {'lambda': 2.1187532238243487, 'alpha': 0.0015129904943059192, 'colsample_bytree': 0.3, 'subsample': 0.4, 'learning_rate': 0.014, 'max_depth': 11, 'min_child_weight': 34}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:14<00:00,  2.88s/it]
# [I 2024-12-18 17:18:20,178] Trial 5 finished with value: 0.37002789801467484 and parameters: {'lambda': 0.25949742778564483, 'alpha': 0.32179370956294273, 'colsample_bytree': 0.3, 'subsample': 0.7, 'learning_rate': 0.012, 'max_depth': 9, 'min_child_weight': 163}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [02:43<00:00, 32.78s/it]
# [I 2024-12-18 17:21:04,101] Trial 6 finished with value: 0.35411374440487225 and parameters: {'lambda': 0.12896806803576966, 'alpha': 0.0020781671435475646, 'colsample_bytree': 1.0, 'subsample': 0.7, 'learning_rate': 0.008, 'max_depth': 15, 'min_child_weight': 6}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:20<00:00,  4.03s/it]
# [I 2024-12-18 17:21:24,258] Trial 7 finished with value: 0.3667294633001318 and parameters: {'lambda': 0.008737991180767958, 'alpha': 0.014379431572835923, 'colsample_bytree': 0.5, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 17, 'min_child_weight': 148}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:17<00:00,  3.44s/it]
# [I 2024-12-18 17:21:41,483] Trial 8 finished with value: 0.3544185180917318 and parameters: {'lambda': 9.242215870688932, 'alpha': 2.845154957331606, 'colsample_bytree': 0.8, 'subsample': 0.5, 'learning_rate': 0.016, 'max_depth': 7, 'min_child_weight': 258}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:45<00:00,  9.06s/it]
# [I 2024-12-18 17:22:26,779] Trial 9 finished with value: 0.36069384802196697 and parameters: {'lambda': 0.07321697502437424, 'alpha': 0.42124896791306277, 'colsample_bytree': 1.0, 'subsample': 1.0, 'learning_rate': 0.014, 'max_depth': 17, 'min_child_weight': 29}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:10<00:00,  2.06s/it]
# [I 2024-12-18 17:22:37,091] Trial 10 finished with value: 0.36074943230040707 and parameters: {'lambda': 0.001384511883942661, 'alpha': 0.03445215977718248, 'colsample_bytree': 0.4, 'subsample': 0.8, 'learning_rate': 0.02, 'max_depth': 13, 'min_child_weight': 286}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:13<00:00,  2.69s/it]
# [I 2024-12-18 17:22:50,584] Trial 11 finished with value: 0.36500845729213544 and parameters: {'lambda': 0.03827011687275578, 'alpha': 0.24833078564579586, 'colsample_bytree': 0.3, 'subsample': 0.6, 'learning_rate': 0.012, 'max_depth': 9, 'min_child_weight': 212}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.24s/it]
# [I 2024-12-18 17:23:01,821] Trial 12 finished with value: 0.36750029020172886 and parameters: {'lambda': 0.38252272726934095, 'alpha': 0.06026230987712569, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.018, 'max_depth': 9, 'min_child_weight': 192}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:10<00:00,  2.15s/it]
# [I 2024-12-18 17:23:12,575] Trial 13 finished with value: 0.36255656421096855 and parameters: {'lambda': 1.27371779536142, 'alpha': 0.018034883325746563, 'colsample_bytree': 0.4, 'subsample': 1.0, 'learning_rate': 0.02, 'max_depth': 9, 'min_child_weight': 214}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:14<00:00,  2.91s/it]
# [I 2024-12-18 17:23:27,141] Trial 14 finished with value: 0.3594819986378798 and parameters: {'lambda': 0.004836007732255757, 'alpha': 0.1369272925379308, 'colsample_bytree': 0.4, 'subsample': 0.5, 'learning_rate': 0.012, 'max_depth': 17, 'min_child_weight': 110}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:12<00:00,  2.53s/it]
# [I 2024-12-18 17:23:39,839] Trial 15 finished with value: 0.36616815347768333 and parameters: {'lambda': 0.12201310877571164, 'alpha': 0.007379328348915818, 'colsample_bytree': 0.3, 'subsample': 0.8, 'learning_rate': 0.02, 'max_depth': 15, 'min_child_weight': 79}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:15<00:00,  3.18s/it]
# [I 2024-12-18 17:23:55,781] Trial 16 finished with value: 0.3578306361792222 and parameters: {'lambda': 0.03189048396795337, 'alpha': 1.0762557431290747, 'colsample_bytree': 0.5, 'subsample': 0.4, 'learning_rate': 0.01, 'max_depth': 13, 'min_child_weight': 183}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.36s/it]
# [I 2024-12-18 17:24:07,619] Trial 17 finished with value: 0.35643118177102817 and parameters: {'lambda': 4.228082559792581, 'alpha': 0.13182991965019802, 'colsample_bytree': 0.9, 'subsample': 0.7, 'learning_rate': 0.016, 'max_depth': 7, 'min_child_weight': 249}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:10<00:00,  2.16s/it]
# [I 2024-12-18 17:24:18,469] Trial 18 finished with value: 0.36832709396503965 and parameters: {'lambda': 0.3741041800986932, 'alpha': 0.005459604533180191, 'colsample_bytree': 0.6, 'subsample': 0.7, 'learning_rate': 0.02, 'max_depth': 9, 'min_child_weight': 166}. Best is trial 0 with value: 0.37176761893035815.
# Training Folds: 100%|██████████| 5/5 [00:16<00:00,  3.25s/it]
# [I 2024-12-18 17:24:34,743] Trial 19 finished with value: 0.3754307032417292 and parameters: {'lambda': 0.1791507681562946, 'alpha': 1.281421067308158, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 87}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:12<00:00,  2.44s/it]
# [I 2024-12-18 17:24:46,960] Trial 20 finished with value: 0.36482247806925683 and parameters: {'lambda': 0.0029490403961197967, 'alpha': 2.1098464153792142, 'colsample_bytree': 0.7, 'subsample': 0.4, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 85}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:15<00:00,  3.17s/it]
# [I 2024-12-18 17:25:02,818] Trial 21 finished with value: 0.3706543501717471 and parameters: {'lambda': 0.19816641296095105, 'alpha': 0.33428930294827724, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 82}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:15<00:00,  3.10s/it]
# [I 2024-12-18 17:25:18,333] Trial 22 finished with value: 0.36069529720905524 and parameters: {'lambda': 0.04606322726286804, 'alpha': 0.06388425625279467, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 80}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:19<00:00,  3.87s/it]
# [I 2024-12-18 17:25:37,702] Trial 23 finished with value: 0.36719964248048853 and parameters: {'lambda': 0.13954070208727445, 'alpha': 9.993813614825088, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 104}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:18<00:00,  3.73s/it]
# [I 2024-12-18 17:25:56,388] Trial 24 finished with value: 0.3680478554239978 and parameters: {'lambda': 0.7109217119495781, 'alpha': 0.9562330887506412, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 60}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.28s/it]
# [I 2024-12-18 17:26:07,838] Trial 25 finished with value: 0.37249993717323415 and parameters: {'lambda': 0.018652168969410722, 'alpha': 2.8930036179119165, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 141}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.31s/it]
# [I 2024-12-18 17:26:19,431] Trial 26 finished with value: 0.3652620722051977 and parameters: {'lambda': 0.017539020889774326, 'alpha': 3.4841924154734123, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 137}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:10<00:00,  2.16s/it]
# [I 2024-12-18 17:26:30,278] Trial 27 finished with value: 0.36259665167476546 and parameters: {'lambda': 0.015161406668254458, 'alpha': 1.7771311305897985, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.02, 'max_depth': 17, 'min_child_weight': 220}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.25s/it]
# [I 2024-12-18 17:26:41,567] Trial 28 finished with value: 0.3717587186285255 and parameters: {'lambda': 0.005868793657595401, 'alpha': 4.30149294985372, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 180}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:19<00:00,  3.91s/it]
# [I 2024-12-18 17:27:01,137] Trial 29 finished with value: 0.3579350717930244 and parameters: {'lambda': 0.04733141439421691, 'alpha': 0.6409949642331876, 'colsample_bytree': 0.8, 'subsample': 1.0, 'learning_rate': 0.014, 'max_depth': 5, 'min_child_weight': 56}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:19<00:00,  3.82s/it]
# [I 2024-12-18 17:27:20,277] Trial 30 finished with value: 0.3647079984857759 and parameters: {'lambda': 0.06700329029617287, 'alpha': 1.5273394790986918, 'colsample_bytree': 0.4, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 7, 'min_child_weight': 151}. Best is trial 19 with value: 0.3754307032417292.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.26s/it]
# [I 2024-12-18 17:27:31,617] Trial 31 finished with value: 0.3755376881292284 and parameters: {'lambda': 0.0063533470401242196, 'alpha': 4.650876387542276, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 188}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.36s/it]
# [I 2024-12-18 17:27:43,425] Trial 32 finished with value: 0.35886776511484497 and parameters: {'lambda': 0.0018178828176320494, 'alpha': 5.389846027446999, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 239}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:13<00:00,  2.67s/it]
# [I 2024-12-18 17:27:56,808] Trial 33 finished with value: 0.37058699857914945 and parameters: {'lambda': 0.020465272580268475, 'alpha': 8.943305005652913, 'colsample_bytree': 0.4, 'subsample': 0.6, 'learning_rate': 0.018, 'max_depth': 17, 'min_child_weight': 197}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:28<00:00,  5.74s/it]
# [I 2024-12-18 17:28:25,512] Trial 34 finished with value: 0.3614134305582309 and parameters: {'lambda': 0.008047539519792011, 'alpha': 5.45342323841713, 'colsample_bytree': 0.9, 'subsample': 0.6, 'learning_rate': 0.008, 'max_depth': 5, 'min_child_weight': 121}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:10<00:00,  2.16s/it]
# [I 2024-12-18 17:28:36,327] Trial 35 finished with value: 0.3720484702189665 and parameters: {'lambda': 0.003153948643349206, 'alpha': 2.460450967372445, 'colsample_bytree': 0.4, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 163}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:10<00:00,  2.16s/it]
# [I 2024-12-18 17:28:47,144] Trial 36 finished with value: 0.3704635416134891 and parameters: {'lambda': 0.0028999453123835796, 'alpha': 2.6393272750309253, 'colsample_bytree': 0.4, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 165}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.20s/it]
# [I 2024-12-18 17:28:58,180] Trial 37 finished with value: 0.37321530815564785 and parameters: {'lambda': 0.002930517898753203, 'alpha': 0.6306730591034664, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 134}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:14<00:00,  2.84s/it]
# [I 2024-12-18 17:29:12,406] Trial 38 finished with value: 0.37366614086257544 and parameters: {'lambda': 0.008657957601607792, 'alpha': 1.3000370878699405, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 98}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:14<00:00,  2.87s/it]
# [I 2024-12-18 17:29:26,791] Trial 39 finished with value: 0.3705610168764992 and parameters: {'lambda': 0.001138391586352881, 'alpha': 0.6092430010808215, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.016, 'max_depth': 11, 'min_child_weight': 100}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:28<00:00,  5.77s/it]
# [I 2024-12-18 17:29:55,646] Trial 40 finished with value: 0.3672593806650172 and parameters: {'lambda': 0.010553001127785795, 'alpha': 1.2088901926813027, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.008, 'max_depth': 11, 'min_child_weight': 57}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:12<00:00,  2.46s/it]
# [I 2024-12-18 17:30:07,978] Trial 41 finished with value: 0.3728590963339437 and parameters: {'lambda': 0.0045468452854251235, 'alpha': 0.6523682153641558, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 133}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:11<00:00,  2.37s/it]
# [I 2024-12-18 17:30:19,877] Trial 42 finished with value: 0.3731527218317229 and parameters: {'lambda': 0.006639601026328633, 'alpha': 0.4912019031484546, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 124}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:12<00:00,  2.49s/it]
# [I 2024-12-18 17:30:32,337] Trial 43 finished with value: 0.3734601365404583 and parameters: {'lambda': 0.009880416621068328, 'alpha': 0.23686750544686755, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 115}. Best is trial 31 with value: 0.3755376881292284.
# Training Folds: 100%|██████████| 5/5 [00:13<00:00,  2.73s/it]
# [I 2024-12-18 17:30:46,038] Trial 44 finished with value: 0.3785175021173627 and parameters: {'lambda': 0.0021716954983024696, 'alpha': 0.2219936339961178, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 100}. Best is trial 44 with value: 0.3785175021173627.
# Training Folds: 100%|██████████| 5/5 [00:13<00:00,  2.80s/it]
# [I 2024-12-18 17:31:00,049] Trial 45 finished with value: 0.3716655827957383 and parameters: {'lambda': 0.010051724981782348, 'alpha': 0.20836522262729165, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.018, 'max_depth': 15, 'min_child_weight': 96}. Best is trial 44 with value: 0.3785175021173627.
# Training Folds: 100%|██████████| 5/5 [00:18<00:00,  3.68s/it]
# [I 2024-12-18 17:31:18,474] Trial 46 finished with value: 0.36687819734056404 and parameters: {'lambda': 0.029555158825351705, 'alpha': 0.24835379374409533, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.014, 'max_depth': 11, 'min_child_weight': 70}. Best is trial 44 with value: 0.3785175021173627.
# Training Folds: 100%|██████████| 5/5 [00:34<00:00,  6.94s/it]
# [I 2024-12-18 17:31:53,211] Trial 47 finished with value: 0.37194089294627924 and parameters: {'lambda': 0.0019311108881379336, 'alpha': 0.16089424837025432, 'colsample_bytree': 1.0, 'subsample': 0.5, 'learning_rate': 0.012, 'max_depth': 13, 'min_child_weight': 22}. Best is trial 44 with value: 0.3785175021173627.
# Training Folds: 100%|██████████| 5/5 [00:12<00:00,  2.48s/it]
# [I 2024-12-18 17:32:05,657] Trial 48 finished with value: 0.3713160053435405 and parameters: {'lambda': 0.0017698780690579238, 'alpha': 0.087407115547577, 'colsample_bytree': 0.8, 'subsample': 0.4, 'learning_rate': 0.018, 'max_depth': 11, 'min_child_weight': 112}. Best is trial 44 with value: 0.3785175021173627.
# Training Folds: 100%|██████████| 5/5 [00:21<00:00,  4.30s/it]
# [I 2024-12-18 17:32:27,170] Trial 49 finished with value: 0.36257981296965947 and parameters: {'lambda': 0.0042428628581625055, 'alpha': 0.030508796167188802, 'colsample_bytree': 0.5, 'subsample': 1.0, 'learning_rate': 0.01, 'max_depth': 11, 'min_child_weight': 91}. Best is trial 44 with value: 0.3785175021173627.

# %%
print(f"\tBest value: {study.best_value:.5f}")
print(f"\tBest params:")

for key, value in study.best_params.items():
    print(f"\t\t{key}: {value}")
# Out:
# 	Best value: 0.37852
# 	Best params:
# 		lambda: 0.0021716954983024696
# 		alpha: 0.2219936339961178
# 		colsample_bytree: 1.0
# 		subsample: 0.5
# 		learning_rate: 0.018
# 		max_depth: 11
# 		min_child_weight: 100

# %%
# Model parameters for LightGBM
Params = {
        'lambda': 0.0021716954983024696,
		'alpha': 0.2219936339961178,
		'colsample_bytree': 1.0,
		'subsample': 0.5,
		'learning_rate': 0.018,
		'max_depth': 11,
		'min_child_weight': 100,
}

XGB = XGBRegressor(**Params,random_state=SEED,n_estimators=10000)

Submission = TrainML(XGB,test)

Submission
# Out:
# Training Folds: 100%|██████████| 5/5 [05:10<00:00, 62.10s/it]
# Mean Train QWK --> 0.9771
# Mean Validation QWK ---> 0.3299
# ----> || Optimized QWK SCORE ::  0.394
#           id  sii
# 0   00008ff9    2
# 1   000fd460    0
# 2   00105258    0
# 3   00115b9f    1
# 4   0016bb22    0
# 5   001f3379    1
# 6   0038ba98    0
# 7   0068a485    0
# 8   0069fbed    1
# 9   0083e397    0
# 10  0087dd65    0
# 11  00abe655    0
# 12  00ae59c9    1
# 13  00af6387    0
# 14  00bd4359    0
# 15  00c0cd71    2
# 16  00d56d4b    0
# 17  00d9913d    0
# 18  00e6167c    0
# 19  00ebc35d    1

# %%
Submission.to_csv('submission2.csv', index=False)
print(Submission['sii'].value_counts())
